# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepjyot-Projects/Pytorch_Basics/blob/main/OpenCv_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Lecture reference: https://www.udemy.com/course/python-for-computer-vision-with-opencv-and-deep-learning/learn/lecture/12257620#questions/10448500
#
#
# the default color value of imshow is different: darker value goes as bluish, and light color goes as yellowish green
#
#
# if u want to show grey images:
#
# 1. cmap = grey
#
#
# others:
# cmap = magma --> dark values diff shades.
#
#
#
#
# important thing(confusing):
#
# image.shape --> gives the (height/rows,width/columns,3)
# but cv2 is ulta, to resize image:  cv2.resize(originalImage, (width,height))
#
# Flip the image:
#
# flip across horizontal acces
# 1. newimg = cv2.flip(img,0)
#
#
# flip across vertical middle axis:
#  1. newimg = cv2.flip(img,1)
#
#
#  both axis: use -1
#   newimg = cv2.flip(img,-1)
#
#
# save the new file:
#
# cv2.imwrite('totallynew.jpg',fix_img)

# %% [markdown]
# Below code shows How to add the canvas space around the image:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import scipy.io
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
img =cv2.imread('/content/drive/My Drive/Udemy-Pytorch-Computer-Vision/Data/00-puppy.jpg')

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-32ad6cb7aa56> in <cell line: 1>()
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
